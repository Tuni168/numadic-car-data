# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from scipy import stats

# %%
data = pd.read_csv("embo21.csv")

# %%
string_columns = data.select_dtypes(include =['object']).columns
float_columns = data.select_dtypes(include =['float64']).columns

# %%
float_summary = data[float_columns].describe

# %%
for col in string_columns:
    data[col + '_length'] = data[col].astype(str).apply(len)

# %%
print("Summary Statistics for Float Columns:")
print(float_summary)
# Out:
# Summary Statistics for Float Columns:
# <bound method NDFrame.describe of         Postal Code  Electric Range     Base MSRP  Legislative District  \
# 0           98407.0            82.0  65762.426230                  27.0
# 1           98368.0            25.0  61743.213601                  24.0
# 2           98070.0            47.0  59748.571844                  34.0
# 3           98642.0            29.0  63259.981573                  18.0
# 4           98337.0           151.0  60399.233656                  26.0
# ...             ...             ...           ...                   ...
# 135033      98362.0            25.0  61743.213601                  24.0
# 135034      98134.0           322.0  69275.305655                  11.0
# 135035      98059.0             0.0  85319.324261                  11.0
# 135036      98225.0             0.0  85319.324261                  42.0
# 135037      98126.0            32.0  41028.686576                  34.0
#
#         2020 Census Tract
# ...

# %%
print("\nSummary Statistics for String Length Columns:")
print(data[[col + '_length' for col in string_columns]].describe())
# Out:
# Summary Statistics for String Length Columns:
#        Identifier_length    City_length    Make_length   Model_length  \
# count           135038.0  135038.000000  135038.000000  135038.000000
# mean                10.0       8.236178       5.546194       6.325790
# std                  0.0       2.330242       1.769908       2.364278
# min                 10.0       3.000000       3.000000       2.000000
# 25%                 10.0       7.000000       5.000000       4.000000
# 50%                 10.0       8.000000       5.000000       7.000000
# 75%                 10.0       9.000000       6.000000       7.000000
# max                 10.0      24.000000      20.000000      24.000000
#
#        Electric Vehicle Type_length  \
# count                 135038.000000
# mean                      31.845762
# std                        3.370362
# min                       30.000000
# 25%                       30.000000
# 50%                       30.000000
# ...

# %%
for col in float_columns:
    # Calculate Z-scores
    z_scores = stats.zscore(data[col])

# %%
   # Define a threshold for outliers (e.g., 3 standard deviations away from the mean)
    threshold = 3
# Out:
#   File "/tmp/ipykernel_251/2567845538.py", line 2
#     threshold = 3
#     ^
# IndentationError: unexpected indent

# %%
iqr_multiplier = 1.5

# %%
threshold = 100  # Example domain-specific threshold

# %%
 outliers = (z_scores > threshold) | (z_scores < -threshold)

# %%
    # Print the indices of outliers
    outlier_indices = data.index[outliers]
    print(f'Outlier indices for {col} length: {outlier_indices}')
# Out:
# Outlier indices for 2020 Census Tract length: Int64Index([], dtype='int64')

# %%
data.head()
# Out:
#    Identifier           City  Postal Code  Model Year       Make        Model  \
# 0  KL8CL6S05E         Tacoma      98407.0        2014  CHEVROLET        SPARK
# 1  JTDKARFP0H  Port Townsend      98368.0        2017     TOYOTA  PRIUS PRIME
# 2  JHMZC5F34J         Vashon      98070.0        2018      HONDA      CLARITY
# 3  KMHC65LD0K     Ridgefield      98642.0        2019    HYUNDAI        IONIQ
# 4  1N4AZ1CP6J      Bremerton      98337.0        2018     NISSAN         LEAF
#
#                     Electric Vehicle Type  \
# 0          Battery Electric Vehicle (BEV)
# 1  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  Plug-in Hybrid Electric Vehicle (PHEV)
# 3  Plug-in Hybrid Electric Vehicle (PHEV)
# 4          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible            82.0
# 1             Not eligible due to low battery range            25.0
# ...

# %%
data.tail()
# Out:
#         Identifier          City  Postal Code  Model Year        Make  \
# 135033  JTDKARFP0H  Port Angeles      98362.0        2017      TOYOTA
# 135034  5YJ3E1EB7L       Seattle      98134.0        2020       TESLA
# 135035  7FCTGAAL4N        Renton      98059.0        2022      RIVIAN
# 135036  WVGGNPE28N    Bellingham      98225.0        2022  VOLKSWAGEN
# 135037  2C4RC1N70L       Seattle      98126.0        2020    CHRYSLER
#
#               Model                   Electric Vehicle Type  \
# 135033  PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 135034      MODEL 3          Battery Electric Vehicle (BEV)
# 135035          R1T          Battery Electric Vehicle (BEV)
# 135036         ID.4          Battery Electric Vehicle (BEV)
# 135037     PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 135033              Not eligible due to low battery range            25.0
# ...

# %%
data.shape
# Out:
# (135038, 23)

# %%
data.columns
# Out:
# Index(['Identifier', 'City', 'Postal Code', 'Model Year', 'Make', 'Model',
#        'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'Vehicle ID', 'Vehicle Location',
#        'Electric Utility', '2020 Census Tract', 'Identifier_length',
#        'City_length', 'Make_length', 'Model_length',
#        'Electric Vehicle Type_length',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility_length',
#        'Vehicle Location_length', 'Electric Utility_length'],
#       dtype='object')

# %%
data.nunique
# Out:
# <bound method DataFrame.nunique of         Identifier           City  Postal Code  Model Year        Make  \
# 0       KL8CL6S05E         Tacoma      98407.0        2014   CHEVROLET
# 1       JTDKARFP0H  Port Townsend      98368.0        2017      TOYOTA
# 2       JHMZC5F34J         Vashon      98070.0        2018       HONDA
# 3       KMHC65LD0K     Ridgefield      98642.0        2019     HYUNDAI
# 4       1N4AZ1CP6J      Bremerton      98337.0        2018      NISSAN
# ...            ...            ...          ...         ...         ...
# 135033  JTDKARFP0H   Port Angeles      98362.0        2017      TOYOTA
# 135034  5YJ3E1EB7L        Seattle      98134.0        2020       TESLA
# 135035  7FCTGAAL4N         Renton      98059.0        2022      RIVIAN
# 135036  WVGGNPE28N     Bellingham      98225.0        2022  VOLKSWAGEN
# 135037  2C4RC1N70L        Seattle      98126.0        2020    CHRYSLER
#
#               Model                   Electric Vehicle Type  \
# ...

# %%
duplicate_rows = data.duplicated().sum()
print("Duplicate Rows:", duplicate_rows)
# Out:
# Duplicate Rows: 0

# %%
summary_statistics = data.describe()
print("Summary Statistics:\n", summary_statistics)
# Out:
# Summary Statistics:
#           Postal Code     Model Year  Electric Range      Base MSRP  \
# count  135030.000000  135038.000000   135037.000000  135037.000000
# mean    98171.001577    2019.662880       74.591964   81017.615211
# std      2450.367211       3.001676       98.744120   23727.350901
# min      1730.000000    1997.000000        0.000000   26455.735798
# 25%     98052.000000    2018.000000        0.000000   63713.207686
# 50%     98121.000000    2021.000000       21.000000   76983.777737
# 75%     98370.000000    2022.000000      150.000000  114632.706686
# max     99701.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District    Vehicle ID  2020 Census Tract  \
# count         134726.000000  1.350380e+05       1.350300e+05
# mean              29.504379  2.063432e+08       5.297233e+10
# std               14.783780  8.582417e+07       1.635783e+09
# min                1.000000  4.385000e+03       1.081042e+09
# ...

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(15, 15))
sns.heatmap(correlation_matrix, annot=True, cmap='plasma')
plt.title('Correlation Matrix')
plt.show()

# %%
correlation_matrix =data.corr()

# %%
sns.distplot(data['Electric Range'])
# Out:
# <AxesSubplot: xlabel='Electric Range', ylabel='Density'>

# %%
for column in data.columns:
    plt.figure(figsize=(30, 30))
    sns.histplot(data[column], kde=True)
    plt.title('Histogram {data}')
    plt.xlabel('Make')
    plt.ylabel('city')
    plt.show()

# %%
for column in data.columns:
    plt.figure(figsize=(30, 30))
    sns.boxplot(x=data[column])
    plt.title( 'Relationshiop' {column}')
    plt.xlabel(count)
    plt.show()
